# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv('heart_disease.csv')

# %%
data.drop(columns=['education'], inplace = True)

# %%
data.dropna(inplace=True)

# %%
data['prevalentStroke'] = data['prevalentStroke'].replace(['yes','no'],[1,0])
# Out:
# C:\Users\Bindushree\AppData\Local\Temp\ipykernel_23520\1543184241.py:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   data['prevalentStroke'] = data['prevalentStroke'].replace(['yes','no'],[1,0])

# %%
data['Heart_ stroke'].unique()
# Out:
# array(['No', 'yes'], dtype=object)

# %%
data['Heart_ stroke'] = data ['Heart_ stroke'].replace(['No','Yes'],[0,1])

# %%
data
# Out:
#       Gender  age  currentSmoker  cigsPerDay  BPMeds  prevalentStroke  \
# 0          1   39              0         0.0     0.0                0
# 1          0   46              0         0.0     0.0                0
# 2          1   48              1        20.0     0.0                0
# 3          0   61              1        30.0     0.0                0
# 4          0   46              1        23.0     0.0                0
# ...      ...  ...            ...         ...     ...              ...
# 4231       1   58              0         0.0     0.0                0
# 4232       1   68              0         0.0     0.0                0
# 4233       1   50              1         1.0     0.0                0
# 4234       1   51              1        43.0     0.0                0
# 4237       0   52              0         0.0     0.0                0
#
#       prevalentHyp  diabetes  totChol  sysBP  diaBP    BMI  heartRate  \
# 0                0         0    195.0  106.0   70.0  26.97       80.0
# 1                0         0    250.0  121.0   81.0  28.73       95.0
# 2                0         0    245.0  127.5   80.0  25.34       75.0
# 3                1         0    225.0  150.0   95.0  28.58       65.0
# 4                0         0    285.0  130.0   84.0  23.10       85.0
# ...            ...       ...      ...    ...    ...    ...        ...
# 4231             1         0    187.0  141.0   81.0  24.96       80.0
# 4232             1         0    176.0  168.0   97.0  23.14       60.0
# 4233             1         0    313.0  179.0   92.0  25.97       66.0
# 4234             0         0    207.0  126.5   80.0  19.71       65.0
# 4237             0         0    269.0  133.5   83.0  21.47       80.0
#
#       glucose Heart_ stroke
# 0        77.0             0
# 1        76.0             0
# 2        70.0             0
# 3       103.0           yes
# 4        85.0             0
# ...       ...           ...
# 4231     81.0             0
# 4232     79.0           yes
# 4233     86.0           yes
# 4234     68.0             0
# 4237    107.0             0
#
# [3749 rows x 15 columns]

# %%
data_input = data.drop(columns=['Heart_ stroke'])
data_output = data['Heart_ stroke']

# %%
data_output.value_counts()
# Out:
# Heart_ stroke
# 0      3177
# yes     572
# Name: count, dtype: int64

# %%
# !pip install imbalanced-learn
# Out:
# Collecting imbalanced-learn
#   Downloading imbalanced_learn-0.14.1-py3-none-any.whl.metadata (8.9 kB)
# Requirement already satisfied: numpy<3,>=1.25.2 in C:\Users\Bindushree\AppData\Local\Programs\Python\Python312\Lib\site-packages (from imbalanced-learn) (2.1.3)
# Requirement already satisfied: scipy<2,>=1.11.4 in C:\Users\Bindushree\AppData\Local\Programs\Python\Python312\Lib\site-packages (from imbalanced-learn) (1.15.2)
# Requirement already satisfied: scikit-learn<2,>=1.4.2 in C:\Users\Bindushree\AppData\Local\Programs\Python\Python312\Lib\site-packages (from imbalanced-learn) (1.6.1)
# Collecting sklearn-compat<0.2,>=0.1.5 (from imbalanced-learn)
#   Downloading sklearn_compat-0.1.5-py3-none-any.whl.metadata (20 kB)
# Requirement already satisfied: joblib<2,>=1.2.0 in C:\Users\Bindushree\AppData\Local\Programs\Python\Python312\Lib\site-packages (from imbalanced-learn) (1.4.2)
# Requirement already satisfied: threadpoolctl<4,>=2.0.0 in C:\Users\Bindushree\AppData\Local\Programs\Python\Python312\Lib\site-packages (from imbalanced-learn) (3.5.0)
# Downloading imbalanced_learn-0.14.1-py3-none-any.whl (235 kB)
# Downloading sklearn_compat-0.1.5-py3-none-any.whl (20 kB)
# Installing collected packages: sklearn-compat, imbalanced-learn
#
#    -------------------- ------------------- 1/2 [imbalanced-learn]
#    -------------------- ------------------- 1/2 [imbalanced-learn]
#    -------------------- ------------------- 1/2 [imbalanced-learn]
#    -------------------- ------------------- 1/2 [imbalanced-learn]
#    -------------------- ------------------- 1/2 [imbalanced-learn]
#    -------------------- ------------------- 1/2 [imbalanced-learn]
#    -------------------- ------------------- 1/2 [imbalanced-learn]
#    -------------------- ------------------- 1/2 [imbalanced-learn]
#    ---------------------------------------- 2/2 [imbalanced-learn]
#
# Successfully installed imbalanced-learn-0.14.1 sklearn-compat-0.1.5
# [notice] A new release of pip is available: 26.0.1 -> 26.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from imblearn.over_sampling import SMOTE

# %%
sm = SMOTE(random_state=2)

# %%
print(data_input.isnull().sum())
# Out:
# Gender             0
# age                0
# currentSmoker      0
# cigsPerDay         0
# BPMeds             0
# prevalentStroke    0
# prevalentHyp       0
# diabetes           0
# totChol            0
# sysBP              0
# diaBP              0
# BMI                0
# heartRate          0
# glucose            0
# dtype: int64

# %%
print(type(data_output))
print(data_output.shape)
# Out:
# <class 'pandas.core.series.Series'>
# (3749,)

# %%
data_output = data_output.squeeze()

# %%
print(data_output.dtype)
print(data_output.unique())
# Out:
# object
# [0 'yes']

# %%
data_output = data_output.replace({'yes': 1, 0: 0})
# Out:
# C:\Users\Bindushree\AppData\Local\Temp\ipykernel_23520\2867263323.py:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   data_output = data_output.replace({'yes': 1, 0: 0})

# %%
data_output = data_output.astype(int)

# %%
from imblearn.over_sampling import SMOTE

sm = SMOTE(random_state=2)

data_input, data_output = sm.fit_resample(data_input, data_output.ravel())
# Out:
# C:\Users\Bindushree\AppData\Local\Temp\ipykernel_23520\3268842285.py:5: FutureWarning: Series.ravel is deprecated. The underlying array is already 1D, so ravel is not necessary.  Use `to_numpy()` for conversion to a numpy array instead.
#   data_input, data_output = sm.fit_resample(data_input, data_output.ravel())

# %%
np.unique(data_output, return_counts=True)
# Out:
# (array([0, 1]), array([3177, 3177]))

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression

# %%
x_train, x_test, y_train, y_test = train_test_split(data_input, data_output, test_size=0.2)

# %%
model = LogisticRegression()

# %%
model.fit(x_train, y_train)
# Out:
# C:\Users\Bindushree\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\linear_model\_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
model.score(x_test, y_test)
# Out:
# 0.6380802517702596

# %%
input = np.array([[0,59,0,0,0,0,1,0,209,150,85,20.77,90,88]])

# %%
x = model.predict(input)
# Out:
# C:\Users\Bindushree\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(

# %%
x[0]
# Out:
# np.int64(1)

# %%
import pickle as pk

# %%
pk.dump(model, open('Heart_disease_model.pkl','wb'))
